# %%
# import dependencies
import pandas as pd
import numpy as np

# %%
# Create a set of 2000 random latitudes and longtitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longtitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import citipy
from citipy import citipy

# %%
# Create a list for holding the cities.
cities=[]
# Identify the nearest city for each latitude and longtitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 767

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval       ")
print("-------------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i in range(len(cities)):
    
    # Group cities in the sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with ea city
    city_url = url + "&q=" + cities[i]
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >=50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with ea city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        #Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that data loading is complete.
print("------------------------------")
print("Data Retrieval is Complete    ")
print("------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 of Set 16 | kurmanayevka
# Processing Record 2 of Set 16 | punta arenas
# Processing Record 3 of Set 16 | puerto ayora
# Processing Record 4 of Set 16 | butaritari
# Processing Record 5 of Set 16 | nikolskoye
# Processing Record 6 of Set 16 | okhotsk
# Processing Record 7 of Set 16 | rikitea
# Processing Record 8 of Set 16 | grindavik
# Processing Record 9 of Set 16 | port blair
# Processing Record 10 of Set 16 | sao felix do xingu
# Processing Record 11 of Set 16 | hamilton
# Processing Record 12 of Set 16 | ancud
# Processing Record 13 of Set 16 | birsk
# Processing Record 14 of Set 16 | biak
# Processing Record 15 of Set 16 | new norfolk
# Processing Record 16 of Set 16 | corn island
# Processing Record 17 of Set 16 | hobart
# Processing Record 18 of Set 16 | sharjah
# Processing Record 19 of Set 16 | busselton
# Processing Record 20 of Set 16 | sarankhola
# Processing Record 21 of Set 16 | marawi
# Processing Record 22 of Set 16 | chuy
# Processing Record 23 of Set 16 | broken hill
# Processing Record 24 of Set 16 | oranjemund
# Processing Record 25 of Set 16 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 16 | hilo
# Processing Record 27 of Set 16 | honggang
# Processing Record 28 of Set 16 | hermanus
# Processing Record 29 of Set 16 | mahebourg
# Processing Record 30 of Set 16 | saint-pierre
# Processing Record 31 of Set 16 | saint-philippe
# Processing Record 32 of Set 16 | macaboboni
# City not found. Skipping...
# Processing Record 33 of Set 16 | kovdor
# Processing Record 34 of Set 16 | pokhvistnevo
# Processing Record 35 of Set 16 | kaitangata
# Processing Record 36 of Set 16 | bluff
# Processing Record 37 of Set 16 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 16 | castro
# Processing Record 39 of Set 16 | kitimat
# Processing Record 40 of Set 16 | tasiilaq
# Processing Record 41 of Set 16 | qaanaaq
# Processing Record 42 of Set 16 | port alfred
# Processing Record 43 of Set 16 | bredasdorp
# Processing Record 44 of Set 16 | albany
# Processing Record 45 of Set 16 | kathua
# Processing Record 46 of Set 16 | dikson
# Processing Record 47 of Set 16 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 16 | yarada
# Processing Record 49 of Set 16 | sechura
# Processing Record 50 of Set 16 | yumen
# Processing Record 1 of Set 17 | ushuaia
# Processing Record 2 of Set 17 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 17 | acarau
# Processing Record 4 of Set 17 | guanica
# Processing Record 5 of Set 17 | zonguldak
# Processing Record 6 of Set 17 | qasigiannguit
# Processing Record 7 of Set 17 | saldanha
# Processing Record 8 of Set 17 | cherskiy
# Processing Record 9 of Set 17 | kodiak
# Processing Record 10 of Set 17 | atuona
# Processing Record 11 of Set 17 | wanaka
# Processing Record 12 of Set 17 | fare
# Processing Record 13 of Set 17 | anna paulowna
# Processing Record 14 of Set 17 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 17 | port macquarie
# Processing Record 16 of Set 17 | egvekinot
# Processing Record 17 of Set 17 | geraldton
# Processing Record 18 of Set 17 | vanino
# Processing Record 19 of Set 17 | miajadas
# Processing Record 20 of Set 17 | ghanzi
# Processing Record 21 of Set 17 | berlevag
# Processing Record 22 of Set 17 | avarua
# Processing Record 23 of Set 17 | istria
# Processing Record 24 of Set 17 | ribeira grande
# Processing Record 25 of Set 17 | georgetown
# Processing Record 26 of Set 17 | arraial do cabo
# Processing Record 27 of Set 17 | saint helens
# Processing Record 28 of Set 17 | marv dasht
# City not found. Skipping...
# Processing Record 29 of Set 17 | pinega
# Processing Record 30 of Set 17 | khatanga
# Processing Record 31 of Set 17 | hornepayne
# Processing Record 32 of Set 17 | faanui
# Processing Record 33 of Set 17 | cape town
# Processing Record 34 of Set 17 | bereda
# Processing Record 35 of Set 17 | lamu
# Processing Record 36 of Set 17 | lingao
# Processing Record 37 of Set 17 | bolungarvik
# City not found. Skipping...
# Processing Record 38 of Set 17 | carnarvon
# Processing Record 39 of Set 17 | lasa
# Processing Record 40 of Set 17 | yatou
# Processing Record 41 of Set 17 | gilgit
# Processing Record 42 of Set 17 | codrington
# Processing Record 43 of Set 17 | east london
# Processing Record 44 of Set 17 | tongchuan
# Processing Record 45 of Set 17 | sri aman
# Processing Record 46 of Set 17 | hirara
# Processing Record 47 of Set 17 | vila velha
# Processing Record 48 of Set 17 | iqaluit
# Processing Record 49 of Set 17 | narsaq
# Processing Record 50 of Set 17 | mudanjiang
# Processing Record 1 of Set 18 | mehran
# Processing Record 2 of Set 18 | naze
# Processing Record 3 of Set 18 | prince rupert
# Processing Record 4 of Set 18 | okotoks
# Processing Record 5 of Set 18 | banepa
# Processing Record 6 of Set 18 | domoni
# Processing Record 7 of Set 18 | upernavik
# Processing Record 8 of Set 18 | daru
# Processing Record 9 of Set 18 | havelock
# Processing Record 10 of Set 18 | dingle
# Processing Record 11 of Set 18 | kawalu
# Processing Record 12 of Set 18 | santa rosa
# Processing Record 13 of Set 18 | kapaa
# Processing Record 14 of Set 18 | nanakuli
# Processing Record 15 of Set 18 | port hedland
# Processing Record 16 of Set 18 | provideniya
# Processing Record 17 of Set 18 | port elizabeth
# Processing Record 18 of Set 18 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 18 | srednekolymsk
# Processing Record 20 of Set 18 | san patricio
# Processing Record 21 of Set 18 | vaini
# Processing Record 22 of Set 18 | aksarka
# Processing Record 23 of Set 18 | tuktoyaktuk
# Processing Record 24 of Set 18 | yellowknife
# Processing Record 25 of Set 18 | mataura
# Processing Record 26 of Set 18 | san carlos de bariloche
# Processing Record 27 of Set 18 | torbay
# Processing Record 28 of Set 18 | constitucion
# Processing Record 29 of Set 18 | bilibino
# Processing Record 30 of Set 18 | jamestown
# Processing Record 31 of Set 18 | fevralsk
# City not found. Skipping...
# Processing Record 32 of Set 18 | plotnikovo
# Processing Record 33 of Set 18 | severo-kurilsk
# Processing Record 34 of Set 18 | wattegama
# Processing Record 35 of Set 18 | matara
# Processing Record 36 of Set 18 | birobidzhan
# Processing Record 37 of Set 18 | porto novo
# Processing Record 38 of Set 18 | orlik
# Processing Record 39 of Set 18 | azul
# Processing Record 40 of Set 18 | ugoofaaru
# Processing Record 41 of Set 18 | huarmey
# Processing Record 42 of Set 18 | airai
# Processing Record 43 of Set 18 | alugan
# Processing Record 44 of Set 18 | biu
# Processing Record 45 of Set 18 | thompson
# Processing Record 46 of Set 18 | dzhusaly
# City not found. Skipping...
# Processing Record 47 of Set 18 | tessalit
# Processing Record 48 of Set 18 | great malvern
# Processing Record 49 of Set 18 | yendi
# Processing Record 50 of Set 18 | atambua
# Processing Record 1 of Set 19 | porto uniao
# Processing Record 2 of Set 19 | harper
# Processing Record 3 of Set 19 | hithadhoo
# Processing Record 4 of Set 19 | balikpapan
# Processing Record 5 of Set 19 | haines junction
# Processing Record 6 of Set 19 | alice springs
# Processing Record 7 of Set 19 | hokitika
# Processing Record 8 of Set 19 | kankan
# Processing Record 9 of Set 19 | victoria
# Processing Record 10 of Set 19 | kaeo
# Processing Record 11 of Set 19 | clyde river
# Processing Record 12 of Set 19 | mogwase
# Processing Record 13 of Set 19 | natal
# Processing Record 14 of Set 19 | misratah
# Processing Record 15 of Set 19 | belaya gora
# Processing Record 16 of Set 19 | marsa matruh
# Processing Record 17 of Set 19 | karagaylinskiy
# Processing Record 18 of Set 19 | kulhudhuffushi
# Processing Record 19 of Set 19 | naryan-mar
# Processing Record 20 of Set 19 | tubruq
# City not found. Skipping...
# Processing Record 21 of Set 19 | port augusta
# Processing Record 22 of Set 19 | mar del plata
# Processing Record 23 of Set 19 | cidreira
# Processing Record 24 of Set 19 | lebu
# Processing Record 25 of Set 19 | khani
# Processing Record 26 of Set 19 | kentau
# Processing Record 27 of Set 19 | mocuba
# Processing Record 28 of Set 19 | fortuna
# Processing Record 29 of Set 19 | tiksi
# Processing Record 30 of Set 19 | labuhan
# Processing Record 31 of Set 19 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 19 | bhuj
# Processing Record 33 of Set 19 | sabang
# Processing Record 34 of Set 19 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 19 | san cristobal
# Processing Record 36 of Set 19 | pisco
# Processing Record 37 of Set 19 | bethel
# Processing Record 38 of Set 19 | tuatapere
# Processing Record 39 of Set 19 | iquique
# Processing Record 40 of Set 19 | olinda
# Processing Record 41 of Set 19 | marystown
# Processing Record 42 of Set 19 | los llanos de aridane
# Processing Record 43 of Set 19 | praia da vitoria
# Processing Record 44 of Set 19 | bengkulu
# Processing Record 45 of Set 19 | mount gambier
# Processing Record 46 of Set 19 | pevek
# Processing Record 47 of Set 19 | sauce
# Processing Record 48 of Set 19 | chokurdakh
# Processing Record 49 of Set 19 | salinopolis
# Processing Record 50 of Set 19 | pozo colorado
# Processing Record 1 of Set 20 | rupert
# Processing Record 2 of Set 20 | saint pete beach
# Processing Record 3 of Set 20 | adelaide
# Processing Record 4 of Set 20 | svirstroy
# Processing Record 5 of Set 20 | paamiut
# Processing Record 6 of Set 20 | leningradskiy
# Processing Record 7 of Set 20 | cerritos
# Processing Record 8 of Set 20 | caraga
# Processing Record 9 of Set 20 | ternate
# Processing Record 10 of Set 20 | vestmannaeyjar
# Processing Record 11 of Set 20 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 20 | karratha
# Processing Record 13 of Set 20 | saskylakh
# Processing Record 14 of Set 20 | krasnaya gorbatka
# Processing Record 15 of Set 20 | luderitz
# Processing Record 16 of Set 20 | dagda
# Processing Record 17 of Set 20 | bathsheba
# Processing Record 18 of Set 20 | jiayuguan
# Processing Record 19 of Set 20 | sinnamary
# Processing Record 20 of Set 20 | kostino
# Processing Record 21 of Set 20 | hailar
# Processing Record 22 of Set 20 | odweyne
# Processing Record 23 of Set 20 | goundam
# Processing Record 24 of Set 20 | isangel
# Processing Record 25 of Set 20 | kavieng
# Processing Record 26 of Set 20 | nome
# Processing Record 27 of Set 20 | hambantota
# Processing Record 28 of Set 20 | melilla
# Processing Record 29 of Set 20 | samfya
# Processing Record 30 of Set 20 | namibe
# Processing Record 31 of Set 20 | vardo
# Processing Record 32 of Set 20 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 20 | birin
# Processing Record 34 of Set 20 | kendari
# Processing Record 35 of Set 20 | nguiu
# City not found. Skipping...
# Processing Record 36 of Set 20 | mahenge
# Processing Record 37 of Set 20 | mancio lima
# Processing Record 38 of Set 20 | port hardy
# Processing Record 39 of Set 20 | tucuman
# Processing Record 40 of Set 20 | ust-nera
# Processing Record 41 of Set 20 | barrow
# Processing Record 42 of Set 20 | faya
# Processing Record 43 of Set 20 | camocim
# Processing Record 44 of Set 20 | praya
# Processing Record 45 of Set 20 | limbang
# Processing Record 46 of Set 20 | cayenne
# Processing Record 47 of Set 20 | santa cruz
# Processing Record 48 of Set 20 | vanimo
# Processing Record 49 of Set 20 | tucurui
# Processing Record 50 of Set 20 | ponta do sol
# Processing Record 1 of Set 21 | londa
# Processing Record 2 of Set 21 | armacao dos buzios
# City not found. Skipping...
# Processing Record 3 of Set 21 | tual
# Processing Record 4 of Set 21 | boshan
# Processing Record 5 of Set 21 | jensen beach
# Processing Record 6 of Set 21 | vostok
# Processing Record 7 of Set 21 | kalengwa
# Processing Record 8 of Set 21 | along
# Processing Record 9 of Set 21 | touros
# Processing Record 10 of Set 21 | fez
# Processing Record 11 of Set 21 | monte patria
# Processing Record 12 of Set 21 | bubaque
# Processing Record 13 of Set 21 | hasaki
# Processing Record 14 of Set 21 | sitka
# Processing Record 15 of Set 21 | jacareacanga
# Processing Record 16 of Set 21 | salalah
# Processing Record 17 of Set 21 | zheleznodorozhnyy
# Processing Record 18 of Set 21 | lompoc
# Processing Record 19 of Set 21 | vao
# Processing Record 20 of Set 21 | esperance
# Processing Record 21 of Set 21 | aljezur
# Processing Record 22 of Set 21 | tamsweg
# Processing Record 23 of Set 21 | troitskoye
# Processing Record 24 of Set 21 | matsanga
# City not found. Skipping...
# Processing Record 25 of Set 21 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 21 | cap malheureux
# Processing Record 27 of Set 21 | podor
# Processing Record 28 of Set 21 | slave lake
# Processing Record 29 of Set 21 | norman wells
# Processing Record 30 of Set 21 | aklavik
# Processing Record 31 of Set 21 | moerai
# Processing Record 32 of Set 21 | brainerd
# Processing Record 33 of Set 21 | paita
# Processing Record 34 of Set 21 | tabuk
# Processing Record 35 of Set 21 | bowen
# Processing Record 36 of Set 21 | imuris
# Processing Record 37 of Set 21 | vila franca do campo
# Processing Record 38 of Set 21 | ciudad bolivar
# Processing Record 39 of Set 21 | kazalinsk
# City not found. Skipping...
# Processing Record 40 of Set 21 | andenes
# Processing Record 41 of Set 21 | chabahar
# Processing Record 42 of Set 21 | bambous virieux
# Processing Record 43 of Set 21 | cairns
# Processing Record 44 of Set 21 | mullaitivu
# City not found. Skipping...
# Processing Record 45 of Set 21 | mabaruma
# Processing Record 46 of Set 21 | lata
# Processing Record 47 of Set 21 | bartica
# Processing Record 48 of Set 21 | wamba
# Processing Record 49 of Set 21 | lubumbashi
# Processing Record 50 of Set 21 | saint george
# Processing Record 1 of Set 22 | umm lajj
# Processing Record 2 of Set 22 | yazman
# Processing Record 3 of Set 22 | raudeberg
# Processing Record 4 of Set 22 | port-cartier
# Processing Record 5 of Set 22 | marzuq
# Processing Record 6 of Set 22 | benidorm
# Processing Record 7 of Set 22 | asau
# Processing Record 8 of Set 22 | doba
# Processing Record 9 of Set 22 | snyder
# Processing Record 10 of Set 22 | malazgirt
# Processing Record 11 of Set 22 | sawakin
# Processing Record 12 of Set 22 | tidore
# City not found. Skipping...
# Processing Record 13 of Set 22 | nalut
# Processing Record 14 of Set 22 | saint anthony
# Processing Record 15 of Set 22 | svalyava
# Processing Record 16 of Set 22 | meulaboh
# Processing Record 17 of Set 22 | krasnoselkup
# Processing Record 18 of Set 22 | hobyo
# Processing Record 19 of Set 22 | guilin
# Processing Record 20 of Set 22 | auki
# Processing Record 21 of Set 22 | cabo san lucas
# Processing Record 22 of Set 22 | vikulovo
# Processing Record 23 of Set 22 | segou
# Processing Record 24 of Set 22 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 22 | mustasaari
# Processing Record 26 of Set 22 | kenai
# Processing Record 27 of Set 22 | skjervoy
# Processing Record 28 of Set 22 | chernyshevskiy
# Processing Record 29 of Set 22 | sao filipe
# Processing Record 30 of Set 22 | college
# Processing Record 31 of Set 22 | savannah bight
# Processing Record 32 of Set 22 | pudozh
# Processing Record 33 of Set 22 | pouebo
# Processing Record 34 of Set 22 | jagdalpur
# Processing Record 35 of Set 22 | ahuimanu
# Processing Record 36 of Set 22 | new iberia
# Processing Record 37 of Set 22 | eyemouth
# Processing Record 38 of Set 22 | praia
# Processing Record 39 of Set 22 | darhan
# Processing Record 40 of Set 22 | burica
# City not found. Skipping...
# Processing Record 41 of Set 22 | pochutla
# Processing Record 42 of Set 22 | mergui
# City not found. Skipping...
# Processing Record 43 of Set 22 | springbok
# Processing Record 44 of Set 22 | sorochinsk
# Processing Record 45 of Set 22 | mogok
# Processing Record 46 of Set 22 | asmara
# Processing Record 47 of Set 22 | sibolga
# Processing Record 48 of Set 22 | veinticinco de mayo
# Processing Record 49 of Set 22 | palana
# Processing Record 50 of Set 22 | mporokoso
# Processing Record 1 of Set 23 | ballina
# Processing Record 2 of Set 23 | raga
# Processing Record 3 of Set 23 | nouadhibou
# Processing Record 4 of Set 23 | puerto leguizamo
# Processing Record 5 of Set 23 | palmerston north
# Processing Record 6 of Set 23 | bahia blanca
# Processing Record 7 of Set 23 | maswa
# Processing Record 8 of Set 23 | suwalki
# Processing Record 9 of Set 23 | abu kamal
# Processing Record 10 of Set 23 | caranavi
# Processing Record 11 of Set 23 | brigantine
# Processing Record 12 of Set 23 | komsomolskiy
# Processing Record 13 of Set 23 | keti bandar
# Processing Record 14 of Set 23 | longyearbyen
# Processing Record 15 of Set 23 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 23 | san andres
# Processing Record 17 of Set 23 | mehamn
# Processing Record 18 of Set 23 | elk river
# Processing Record 19 of Set 23 | coihaique
# Processing Record 20 of Set 23 | shubarshi
# Processing Record 21 of Set 23 | rawson
# Processing Record 22 of Set 23 | taltal
# Processing Record 23 of Set 23 | radyvyliv
# Processing Record 24 of Set 23 | necochea
# Processing Record 25 of Set 23 | zalari
# Processing Record 26 of Set 23 | villanueva
# Processing Record 27 of Set 23 | lieksa
# Processing Record 28 of Set 23 | ambodifototra
# City not found. Skipping...
# Processing Record 29 of Set 23 | nikki
# Processing Record 30 of Set 23 | laguna
# Processing Record 31 of Set 23 | urucui
# Processing Record 32 of Set 23 | katherine
# Processing Record 33 of Set 23 | yeppoon
# Processing Record 34 of Set 23 | saint-joseph
# Processing Record 35 of Set 23 | shalakusha
# Processing Record 36 of Set 23 | gao
# Processing Record 37 of Set 23 | bargal
# City not found. Skipping...
# Processing Record 38 of Set 23 | oranjestad
# Processing Record 39 of Set 23 | mrirt
# City not found. Skipping...
# Processing Record 40 of Set 23 | maurepas
# Processing Record 41 of Set 23 | grand-santi
# Processing Record 42 of Set 23 | gazanjyk
# Processing Record 43 of Set 23 | mantes-la-ville
# Processing Record 44 of Set 23 | kloulklubed
# Processing Record 45 of Set 23 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 23 | elat
# Processing Record 47 of Set 23 | olafsvik
# Processing Record 48 of Set 23 | cooma
# Processing Record 49 of Set 23 | uchaly
# Processing Record 50 of Set 23 | kashi
# Processing Record 1 of Set 24 | ahipara
# Processing Record 2 of Set 24 | cartagena
# Processing Record 3 of Set 24 | rumphi
# Processing Record 4 of Set 24 | livezile
# Processing Record 5 of Set 24 | kindia
# Processing Record 6 of Set 24 | thinadhoo
# Processing Record 7 of Set 24 | fairbanks
# Processing Record 8 of Set 24 | quatre cocos
# Processing Record 9 of Set 24 | maarianhamina
# Processing Record 10 of Set 24 | ilulissat
# Processing Record 11 of Set 24 | kosh-agach
# Processing Record 12 of Set 24 | inongo
# Processing Record 13 of Set 24 | kieta
# Processing Record 14 of Set 24 | havoysund
# Processing Record 15 of Set 24 | luau
# Processing Record 16 of Set 24 | gornopravdinsk
# Processing Record 17 of Set 24 | matagami
# Processing Record 18 of Set 24 | shatsk
# Processing Record 19 of Set 24 | katsuura
# Processing Record 20 of Set 24 | payakumbuh
# Processing Record 21 of Set 24 | beloha
# Processing Record 22 of Set 24 | shar
# Processing Record 23 of Set 24 | tapaua
# City not found. Skipping...
# Processing Record 24 of Set 24 | tizimin
# Processing Record 25 of Set 24 | padilla
# Processing Record 26 of Set 24 | anshun
# Processing Record 27 of Set 24 | pimentel
# Processing Record 28 of Set 24 | kalevala
# Processing Record 29 of Set 24 | alofi
# Processing Record 30 of Set 24 | kankon
# Processing Record 31 of Set 24 | ornskoldsvik
# Processing Record 32 of Set 24 | henties bay
# Processing Record 33 of Set 24 | moramanga
# Processing Record 34 of Set 24 | talnakh
# Processing Record 35 of Set 24 | leh
# Processing Record 36 of Set 24 | tautira
# Processing Record 37 of Set 24 | durres
# Processing Record 38 of Set 24 | tres de maio
# Processing Record 39 of Set 24 | road town
# Processing Record 40 of Set 24 | byron bay
# Processing Record 41 of Set 24 | guerrero negro
# Processing Record 42 of Set 24 | dunedin
# Processing Record 43 of Set 24 | walvis bay
# Processing Record 44 of Set 24 | rio grande
# Processing Record 45 of Set 24 | santa vitoria do palmar
# Processing Record 46 of Set 24 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 24 | touba
# Processing Record 48 of Set 24 | north bend
# Processing Record 49 of Set 24 | manicore
# Processing Record 50 of Set 24 | andros town
# Processing Record 1 of Set 25 | maceio
# Processing Record 2 of Set 25 | morondava
# Processing Record 3 of Set 25 | weyburn
# Processing Record 4 of Set 25 | maroua
# Processing Record 5 of Set 25 | vangaindrano
# Processing Record 6 of Set 25 | puerto madero
# Processing Record 7 of Set 25 | porto walter
# Processing Record 8 of Set 25 | lubango
# Processing Record 9 of Set 25 | hit
# Processing Record 10 of Set 25 | lavrentiya
# Processing Record 11 of Set 25 | upata
# Processing Record 12 of Set 25 | tongliao
# Processing Record 13 of Set 25 | itabuna
# Processing Record 14 of Set 25 | smithers
# Processing Record 15 of Set 25 | pontianak
# Processing Record 16 of Set 25 | gat
# Processing Record 17 of Set 25 | fukue
# Processing Record 18 of Set 25 | kavaratti
# Processing Record 19 of Set 25 | amherst
# Processing Record 20 of Set 25 | chokwe
# Processing Record 21 of Set 25 | la palma
# Processing Record 22 of Set 25 | brae
# Processing Record 23 of Set 25 | sur
# Processing Record 24 of Set 25 | chifeng
# Processing Record 25 of Set 25 | pont-rouge
# Processing Record 26 of Set 25 | itarema
# Processing Record 27 of Set 25 | fort-shevchenko
# Processing Record 28 of Set 25 | paray-le-monial
# Processing Record 29 of Set 25 | chavakkad
# Processing Record 30 of Set 25 | pueblo nuevo
# Processing Record 31 of Set 25 | isetskoye
# Processing Record 32 of Set 25 | venado tuerto
# Processing Record 33 of Set 25 | yerbogachen
# Processing Record 34 of Set 25 | baley
# Processing Record 35 of Set 25 | sahrak
# City not found. Skipping...
# Processing Record 36 of Set 25 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 37 of Set 25 | canoa
# Processing Record 38 of Set 25 | moissala
# Processing Record 39 of Set 25 | pedernales
# Processing Record 40 of Set 25 | bardiyah
# Processing Record 41 of Set 25 | kangaatsiaq
# Processing Record 42 of Set 25 | hualmay
# Processing Record 43 of Set 25 | pacific grove
# Processing Record 44 of Set 25 | rajbiraj
# Processing Record 45 of Set 25 | revda
# Processing Record 46 of Set 25 | constantine
# Processing Record 47 of Set 25 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 25 | singarayakonda
# Processing Record 49 of Set 25 | najran
# Processing Record 50 of Set 25 | chagda
# City not found. Skipping...
# Processing Record 1 of Set 26 | yulara
# Processing Record 2 of Set 26 | mount isa
# Processing Record 3 of Set 26 | karauzyak
# City not found. Skipping...
# Processing Record 4 of Set 26 | vaitape
# Processing Record 5 of Set 26 | vrangel
# Processing Record 6 of Set 26 | maryborough
# Processing Record 7 of Set 26 | camacupa
# Processing Record 8 of Set 26 | ambilobe
# Processing Record 9 of Set 26 | jimeta
# Processing Record 10 of Set 26 | christchurch
# Processing Record 11 of Set 26 | dakar
# Processing Record 12 of Set 26 | karatau
# Processing Record 13 of Set 26 | bambanglipuro
# Processing Record 14 of Set 26 | westport
# Processing Record 15 of Set 26 | te anau
# Processing Record 16 of Set 26 | barkhan
# Processing Record 17 of Set 26 | kruisfontein
# Processing Record 18 of Set 26 | lorengau
# Processing Record 19 of Set 26 | yarmouth
# Processing Record 20 of Set 26 | yacuiba
# Processing Record 21 of Set 26 | aland
# Processing Record 22 of Set 26 | cockburn town
# Processing Record 23 of Set 26 | hundested
# Processing Record 24 of Set 26 | nova olimpia
# Processing Record 25 of Set 26 | kuala terengganu
# Processing Record 26 of Set 26 | poum
# Processing Record 27 of Set 26 | khromtau
# Processing Record 28 of Set 26 | shetpe
# Processing Record 29 of Set 26 | kahului
# Processing Record 30 of Set 26 | yaring
# Processing Record 31 of Set 26 | beira
# Processing Record 32 of Set 26 | parral
# Processing Record 33 of Set 26 | acari
# Processing Record 34 of Set 26 | sao lourenco do oeste
# Processing Record 35 of Set 26 | namatanai
# Processing Record 36 of Set 26 | zhongshu
# Processing Record 37 of Set 26 | spassk
# Processing Record 38 of Set 26 | puerto suarez
# Processing Record 39 of Set 26 | kabompo
# Processing Record 40 of Set 26 | phan thiet
# Processing Record 41 of Set 26 | kaseda
# Processing Record 42 of Set 26 | aswan
# Processing Record 43 of Set 26 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 26 | oga
# Processing Record 45 of Set 26 | kununurra
# Processing Record 46 of Set 26 | muros
# Processing Record 47 of Set 26 | ondjiva
# Processing Record 48 of Set 26 | roma
# Processing Record 49 of Set 26 | jalu
# Processing Record 50 of Set 26 | rincon
# Processing Record 1 of Set 27 | ostrovnoy
# Processing Record 2 of Set 27 | yelizovo
# Processing Record 3 of Set 27 | hvide sande
# Processing Record 4 of Set 27 | aitape
# Processing Record 5 of Set 27 | satitoa
# City not found. Skipping...
# Processing Record 6 of Set 27 | khandyga
# Processing Record 7 of Set 27 | madisonville
# Processing Record 8 of Set 27 | rocha
# Processing Record 9 of Set 27 | roebourne
# Processing Record 10 of Set 27 | wuda
# Processing Record 11 of Set 27 | makakilo city
# Processing Record 12 of Set 27 | pangnirtung
# Processing Record 13 of Set 27 | dapaong
# Processing Record 14 of Set 27 | mogadishu
# Processing Record 15 of Set 27 | poole
# Processing Record 16 of Set 27 | zharkent
# Processing Record 17 of Set 27 | tilichiki
# Processing Record 18 of Set 27 | sorvag
# City not found. Skipping...
# Processing Record 19 of Set 27 | luwingu
# Processing Record 20 of Set 27 | plettenberg bay
# Processing Record 21 of Set 27 | umm kaddadah
# Processing Record 22 of Set 27 | kiunga
# Processing Record 23 of Set 27 | ziniare
# Processing Record 24 of Set 27 | noumea
# Processing Record 25 of Set 27 | kurilsk
# Processing Record 26 of Set 27 | great falls
# Processing Record 27 of Set 27 | rochefort
# Processing Record 28 of Set 27 | chelbasskaya
# Processing Record 29 of Set 27 | akyab
# Processing Record 30 of Set 27 | nsanje
# Processing Record 31 of Set 27 | bandarbeyla
# Processing Record 32 of Set 27 | nemuro
# Processing Record 33 of Set 27 | juneau
# Processing Record 34 of Set 27 | tolaga bay
# Processing Record 35 of Set 27 | ormara
# Processing Record 36 of Set 27 | riachao
# Processing Record 37 of Set 27 | kandrian
# Processing Record 38 of Set 27 | thouars
# Processing Record 39 of Set 27 | lagos
# Processing Record 40 of Set 27 | northam
# Processing Record 41 of Set 27 | abha
# Processing Record 42 of Set 27 | namwala
# Processing Record 43 of Set 27 | sambava
# Processing Record 44 of Set 27 | kamenskoye
# City not found. Skipping...
# Processing Record 45 of Set 27 | wilmington
# Processing Record 46 of Set 27 | sumter
# Processing Record 47 of Set 27 | barra patuca
# Processing Record 48 of Set 27 | umkomaas
# Processing Record 49 of Set 27 | dongargaon
# Processing Record 50 of Set 27 | eirunepe
# Processing Record 1 of Set 28 | grand gaube
# Processing Record 2 of Set 28 | wagga wagga
# Processing Record 3 of Set 28 | merauke
# Processing Record 4 of Set 28 | talara
# Processing Record 5 of Set 28 | aasiaat
# Processing Record 6 of Set 28 | tacuarembo
# Processing Record 7 of Set 28 | louisbourg
# City not found. Skipping...
# Processing Record 8 of Set 28 | vila do maio
# Processing Record 9 of Set 28 | erice
# Processing Record 10 of Set 28 | summerville
# Processing Record 11 of Set 28 | krasnorechenskiy
# Processing Record 12 of Set 28 | quelimane
# Processing Record 13 of Set 28 | acapulco
# Processing Record 14 of Set 28 | shitanjing
# Processing Record 15 of Set 28 | san luis
# Processing Record 16 of Set 28 | san jose
# Processing Record 17 of Set 28 | nongan
# Processing Record 18 of Set 28 | kashan
# Processing Record 19 of Set 28 | galiwinku
# City not found. Skipping...
# Processing Record 20 of Set 28 | xai-xai
# Processing Record 21 of Set 28 | svetlogorsk
# Processing Record 22 of Set 28 | xam nua
# Processing Record 23 of Set 28 | la ronge
# Processing Record 24 of Set 28 | rovaniemi
# Processing Record 25 of Set 28 | gayny
# Processing Record 26 of Set 28 | salinas
# Processing Record 27 of Set 28 | mayo
# Processing Record 28 of Set 28 | finnsnes
# Processing Record 29 of Set 28 | santa isabel
# Processing Record 30 of Set 28 | trois-rivieres
# Processing Record 31 of Set 28 | tullamore
# Processing Record 32 of Set 28 | broome
# Processing Record 33 of Set 28 | skelleftea
# Processing Record 34 of Set 28 | darnah
# Processing Record 35 of Set 28 | goderich
# Processing Record 36 of Set 28 | bolshaya murta
# City not found. Skipping...
# Processing Record 37 of Set 28 | ondangwa
# Processing Record 38 of Set 28 | bilma
# Processing Record 39 of Set 28 | farrukhnagar
# Processing Record 40 of Set 28 | half moon bay
# Processing Record 41 of Set 28 | mizpe ramon
# City not found. Skipping...
# Processing Record 42 of Set 28 | rongcheng
# Processing Record 43 of Set 28 | alyangula
# Processing Record 44 of Set 28 | artigas
# Processing Record 45 of Set 28 | gazojak
# Processing Record 46 of Set 28 | bud
# Processing Record 47 of Set 28 | mbandaka
# Processing Record 48 of Set 28 | malangali
# Processing Record 49 of Set 28 | halalo
# City not found. Skipping...
# Processing Record 50 of Set 28 | dubinino
# Processing Record 1 of Set 29 | viedma
# Processing Record 2 of Set 29 | chake chake
# Processing Record 3 of Set 29 | seoul
# Processing Record 4 of Set 29 | peniche
# Processing Record 5 of Set 29 | chervona sloboda
# Processing Record 6 of Set 29 | maloshuyka
# City not found. Skipping...
# Processing Record 7 of Set 29 | sohbatpur
# Processing Record 8 of Set 29 | tezu
# Processing Record 9 of Set 29 | char bhadrasan
# Processing Record 10 of Set 29 | rehoboth
# Processing Record 11 of Set 29 | iquitos
# Processing Record 12 of Set 29 | druzhba
# Processing Record 13 of Set 29 | lagoa
# Processing Record 14 of Set 29 | zavetnoye
# Processing Record 15 of Set 29 | katobu
# Processing Record 16 of Set 29 | mahaicony
# City not found. Skipping...
# Processing Record 17 of Set 29 | chhabra
# Processing Record 18 of Set 29 | taveta
# Processing Record 19 of Set 29 | curuca
# Processing Record 20 of Set 29 | ziarat
# Processing Record 21 of Set 29 | erdenet
# Processing Record 22 of Set 29 | barinas
# Processing Record 23 of Set 29 | cabedelo
# Processing Record 24 of Set 29 | soyo
# Processing Record 25 of Set 29 | varna
# Processing Record 26 of Set 29 | xique-xique
# Processing Record 27 of Set 29 | surgut
# Processing Record 28 of Set 29 | nokaneng
# Processing Record 29 of Set 29 | yaan
# Processing Record 30 of Set 29 | rosarito
# Processing Record 31 of Set 29 | bousse
# Processing Record 32 of Set 29 | azanka
# Processing Record 33 of Set 29 | avera
# Processing Record 34 of Set 29 | la asuncion
# Processing Record 35 of Set 29 | dezful
# Processing Record 36 of Set 29 | tabou
# Processing Record 37 of Set 29 | rafraf
# Processing Record 38 of Set 29 | pafos
# Processing Record 39 of Set 29 | juba
# Processing Record 40 of Set 29 | quepos
# Processing Record 41 of Set 29 | tingi
# Processing Record 42 of Set 29 | manado
# Processing Record 43 of Set 29 | gobabis
# Processing Record 44 of Set 29 | espanola
# Processing Record 45 of Set 29 | utiroa
# City not found. Skipping...
# Processing Record 46 of Set 29 | anadyr
# Processing Record 47 of Set 29 | sept-iles
# Processing Record 48 of Set 29 | ostersund
# Processing Record 49 of Set 29 | belluno
# Processing Record 50 of Set 29 | soledade
# Processing Record 1 of Set 30 | chivay
# Processing Record 2 of Set 30 | konevo
# Processing Record 3 of Set 30 | belmonte
# Processing Record 4 of Set 30 | dinsor
# City not found. Skipping...
# Processing Record 5 of Set 30 | waddan
# Processing Record 6 of Set 30 | zlobin
# Processing Record 7 of Set 30 | erenhot
# Processing Record 8 of Set 30 | xiamen
# Processing Record 9 of Set 30 | aksu
# Processing Record 10 of Set 30 | pimenta bueno
# Processing Record 11 of Set 30 | chistoye
# Processing Record 12 of Set 30 | bu salim
# City not found. Skipping...
# Processing Record 13 of Set 30 | nuuk
# Processing Record 14 of Set 30 | kattivakkam
# Processing Record 15 of Set 30 | amapa
# Processing Record 16 of Set 30 | zhuji
# Processing Record 17 of Set 30 | dwarka
# Processing Record 18 of Set 30 | itoman
# Processing Record 19 of Set 30 | kamenka
# Processing Record 20 of Set 30 | bratsk
# Processing Record 21 of Set 30 | senador guiomard
# Processing Record 22 of Set 30 | pavlodar
# Processing Record 23 of Set 30 | margate
# Processing Record 24 of Set 30 | fort nelson
# Processing Record 25 of Set 30 | bridgton
# Processing Record 26 of Set 30 | usman
# Processing Record 27 of Set 30 | sorata
# Processing Record 28 of Set 30 | boddam
# Processing Record 29 of Set 30 | kazanovka
# City not found. Skipping...
# Processing Record 30 of Set 30 | ialibu
# Processing Record 31 of Set 30 | sawtell
# Processing Record 32 of Set 30 | poselki
# Processing Record 33 of Set 30 | marang
# Processing Record 34 of Set 30 | qaqortoq
# Processing Record 35 of Set 30 | borovskoy
# Processing Record 36 of Set 30 | lake forest
# Processing Record 37 of Set 30 | teya
# Processing Record 38 of Set 30 | privolzhye
# Processing Record 39 of Set 30 | manthani
# Processing Record 40 of Set 30 | guhagar
# Processing Record 41 of Set 30 | masuguru
# Processing Record 42 of Set 30 | annau
# Processing Record 43 of Set 30 | zhigansk
# Processing Record 44 of Set 30 | ambon
# Processing Record 45 of Set 30 | morant bay
# Processing Record 46 of Set 30 | srandakan
# Processing Record 47 of Set 30 | wheeling
# Processing Record 48 of Set 30 | sarakhs
# Processing Record 49 of Set 30 | shingu
# Processing Record 50 of Set 30 | topeka
# Processing Record 1 of Set 31 | shimoda
# Processing Record 2 of Set 31 | sampit
# Processing Record 3 of Set 31 | tunduru
# City not found. Skipping...
# Processing Record 4 of Set 31 | chicama
# Processing Record 5 of Set 31 | ajdabiya
# Processing Record 6 of Set 31 | pechenizhyn
# Processing Record 7 of Set 31 | ngunguru
# Processing Record 8 of Set 31 | pangai
# Processing Record 9 of Set 31 | angra
# City not found. Skipping...
# Processing Record 10 of Set 31 | magadan
# Processing Record 11 of Set 31 | yantal
# Processing Record 12 of Set 31 | jinxiang
# Processing Record 13 of Set 31 | maldonado
# Processing Record 14 of Set 31 | bani walid
# Processing Record 15 of Set 31 | coahuayana
# Processing Record 16 of Set 31 | bonito
# Processing Record 17 of Set 31 | poronaysk
# ------------------------------
# Data Retrieval is Complete
# ------------------------------

# %%
len(city_data)
# Out:
# 713

# %%
# Convert the array to pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Kurmanayevka  52.5093   52.0675     45.37        93         100
# 1        Punta Arenas -53.1500  -70.9167     42.80       100          75
# 2        Puerto Ayora  -0.7393  -90.3518     77.00        96          11
# 3          Butaritari   3.0707  172.7902     81.82        75         100
# 4          Nikolskoye  59.7035   30.7861     39.00        93          75
# 5             Okhotsk  59.3833  143.3000     32.00        56           9
# 6             Rikitea -23.1203 -134.9692     78.98        74         100
# 7           Grindavik  63.8424  -22.4338     46.40        93          75
# 8          Port Blair  11.6667   92.7500     89.60        66          40
# 9  Sao Felix Do Xingu  -6.6447  -51.9950     70.93        98          35
#
#    Wind Speed Country Current Description
# 0        3.78      RU     overcast clouds
# 1        3.44      CL       broken clouds
# 2        5.01      EC          few clouds
# 3        7.56      KI          light rain
# 4        4.47      RU       broken clouds
# 5       13.80      RU           clear sky
# 6       15.77      PF     overcast clouds
# 7       21.85      IS       broken clouds
# 8        5.75      IN    scattered clouds
# 9        0.94      BR    scattered clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]

city_data_df.head(10)
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0        Kurmanayevka      RU  52.5093   52.0675     45.37        93
# 1        Punta Arenas      CL -53.1500  -70.9167     42.80       100
# 2        Puerto Ayora      EC  -0.7393  -90.3518     77.00        96
# 3          Butaritari      KI   3.0707  172.7902     81.82        75
# 4          Nikolskoye      RU  59.7035   30.7861     39.00        93
# 5             Okhotsk      RU  59.3833  143.3000     32.00        56
# 6             Rikitea      PF -23.1203 -134.9692     78.98        74
# 7           Grindavik      IS  63.8424  -22.4338     46.40        93
# 8          Port Blair      IN  11.6667   92.7500     89.60        66
# 9  Sao Felix Do Xingu      BR  -6.6447  -51.9950     70.93        98
#
#    Cloudiness  Wind Speed Current Description
# 0         100        3.78     overcast clouds
# 1          75        3.44       broken clouds
# 2          11        5.01          few clouds
# 3         100        7.56          light rain
# 4          75        4.47       broken clouds
# 5           9       13.80           clear sky
# 6         100       15.77     overcast clouds
# 7          75       21.85       broken clouds
# 8          40        5.75    scattered clouds
# 9          35        0.94    scattered clouds

# %%
# Create the output file (CSV)
output_data_file = "Weather_Database/cities.csv"
# Export the City_Data into CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
