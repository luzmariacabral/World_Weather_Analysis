# %%
# import dependencies
import pandas as pd
import numpy as np

# %%
# Create a set of 2000 random latitudes and longtitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longtitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import citipy
from citipy import citipy

# %%
# Create a list for holding the cities.
cities=[]
# Identify the nearest city for each latitude and longtitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 762

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval       ")
print("-------------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i in range(len(cities)):
    
    # Group cities in the sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with ea city
    city_url = url + "&q=" + cities[i]
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >=50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with ea city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        #Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that data loading is complete.
print("------------------------------")
print("Data Retrieval is Complete    ")
print("------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 of Set 16 | zhigansk
# Processing Record 2 of Set 16 | sisimiut
# Processing Record 3 of Set 16 | chokurdakh
# Processing Record 4 of Set 16 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 16 | diego de almagro
# Processing Record 6 of Set 16 | vila franca do campo
# Processing Record 7 of Set 16 | cabo san lucas
# Processing Record 8 of Set 16 | rikitea
# Processing Record 9 of Set 16 | coihaique
# Processing Record 10 of Set 16 | hilo
# Processing Record 11 of Set 16 | cape town
# Processing Record 12 of Set 16 | thika
# Processing Record 13 of Set 16 | aklavik
# Processing Record 14 of Set 16 | kaitangata
# Processing Record 15 of Set 16 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 16 | tasiilaq
# Processing Record 17 of Set 16 | pacific grove
# Processing Record 18 of Set 16 | albany
# Processing Record 19 of Set 16 | punta arenas
# Processing Record 20 of Set 16 | thompson
# Processing Record 21 of Set 16 | lebu
# Processing Record 22 of Set 16 | kirakira
# Processing Record 23 of Set 16 | dikson
# Processing Record 24 of Set 16 | itoman
# Processing Record 25 of Set 16 | busselton
# Processing Record 26 of Set 16 | san ramon
# Processing Record 27 of Set 16 | ostersund
# Processing Record 28 of Set 16 | san luis
# Processing Record 29 of Set 16 | morti
# City not found. Skipping...
# Processing Record 30 of Set 16 | vaini
# Processing Record 31 of Set 16 | yellowknife
# Processing Record 32 of Set 16 | mahebourg
# Processing Record 33 of Set 16 | kapaa
# Processing Record 34 of Set 16 | balykshi
# Processing Record 35 of Set 16 | mount gambier
# Processing Record 36 of Set 16 | sao filipe
# Processing Record 37 of Set 16 | provideniya
# Processing Record 38 of Set 16 | vestmanna
# Processing Record 39 of Set 16 | manicore
# Processing Record 40 of Set 16 | talnakh
# Processing Record 41 of Set 16 | sain alto
# Processing Record 42 of Set 16 | carnarvon
# Processing Record 43 of Set 16 | saint-augustin
# Processing Record 44 of Set 16 | ushuaia
# Processing Record 45 of Set 16 | yunjinghong
# City not found. Skipping...
# Processing Record 46 of Set 16 | coahuayana
# Processing Record 47 of Set 16 | andenes
# Processing Record 48 of Set 16 | nome
# Processing Record 49 of Set 16 | suntar
# Processing Record 50 of Set 16 | sidi bu zayd
# City not found. Skipping...
# Processing Record 1 of Set 17 | lata
# Processing Record 2 of Set 17 | martapura
# Processing Record 3 of Set 17 | ahipara
# Processing Record 4 of Set 17 | san joaquin
# Processing Record 5 of Set 17 | alofi
# Processing Record 6 of Set 17 | souillac
# Processing Record 7 of Set 17 | tuatapere
# Processing Record 8 of Set 17 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 17 | luderitz
# Processing Record 10 of Set 17 | nantucket
# Processing Record 11 of Set 17 | tahta
# Processing Record 12 of Set 17 | wageningen
# Processing Record 13 of Set 17 | lodwar
# Processing Record 14 of Set 17 | mataura
# Processing Record 15 of Set 17 | lantana
# Processing Record 16 of Set 17 | esperance
# Processing Record 17 of Set 17 | new norfolk
# Processing Record 18 of Set 17 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 17 | georgetown
# Processing Record 20 of Set 17 | tiksi
# Processing Record 21 of Set 17 | salalah
# Processing Record 22 of Set 17 | bathsheba
# Processing Record 23 of Set 17 | lompoc
# Processing Record 24 of Set 17 | victoria
# Processing Record 25 of Set 17 | umm durman
# City not found. Skipping...
# Processing Record 26 of Set 17 | saint george
# Processing Record 27 of Set 17 | qaanaaq
# Processing Record 28 of Set 17 | bredasdorp
# Processing Record 29 of Set 17 | monchegorsk
# Processing Record 30 of Set 17 | tenkodogo
# Processing Record 31 of Set 17 | yar-sale
# Processing Record 32 of Set 17 | hasaki
# Processing Record 33 of Set 17 | jalu
# Processing Record 34 of Set 17 | maraa
# Processing Record 35 of Set 17 | hofn
# Processing Record 36 of Set 17 | hithadhoo
# Processing Record 37 of Set 17 | haines junction
# Processing Record 38 of Set 17 | lavrentiya
# Processing Record 39 of Set 17 | hobart
# Processing Record 40 of Set 17 | charagua
# Processing Record 41 of Set 17 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 17 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 17 | olavarria
# Processing Record 44 of Set 17 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 45 of Set 17 | ribeira grande
# Processing Record 46 of Set 17 | tuktoyaktuk
# Processing Record 47 of Set 17 | great falls
# Processing Record 48 of Set 17 | hermanus
# Processing Record 49 of Set 17 | nanortalik
# Processing Record 50 of Set 17 | bluff
# Processing Record 1 of Set 18 | ape
# Processing Record 2 of Set 18 | katsuura
# Processing Record 3 of Set 18 | rawson
# Processing Record 4 of Set 18 | havre-saint-pierre
# Processing Record 5 of Set 18 | bowen
# Processing Record 6 of Set 18 | olinda
# Processing Record 7 of Set 18 | butaritari
# Processing Record 8 of Set 18 | gambela
# Processing Record 9 of Set 18 | manggar
# Processing Record 10 of Set 18 | cap malheureux
# Processing Record 11 of Set 18 | avarua
# Processing Record 12 of Set 18 | villa bruzual
# Processing Record 13 of Set 18 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 18 | san quintin
# Processing Record 15 of Set 18 | dingle
# Processing Record 16 of Set 18 | iqaluit
# Processing Record 17 of Set 18 | faanui
# Processing Record 18 of Set 18 | port-gentil
# Processing Record 19 of Set 18 | bubaque
# Processing Record 20 of Set 18 | kachikau
# City not found. Skipping...
# Processing Record 21 of Set 18 | hami
# Processing Record 22 of Set 18 | phrae
# Processing Record 23 of Set 18 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 18 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 18 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 18 | juneau
# Processing Record 27 of Set 18 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 18 | antropovo
# Processing Record 29 of Set 18 | fortuna
# Processing Record 30 of Set 18 | puerto ayora
# Processing Record 31 of Set 18 | stokmarknes
# Processing Record 32 of Set 18 | saint-philippe
# Processing Record 33 of Set 18 | howard springs
# Processing Record 34 of Set 18 | nikolskoye
# Processing Record 35 of Set 18 | san lawrenz
# Processing Record 36 of Set 18 | olafsvik
# Processing Record 37 of Set 18 | ahmadpur sial
# Processing Record 38 of Set 18 | atuona
# Processing Record 39 of Set 18 | clyde river
# Processing Record 40 of Set 18 | teguise
# Processing Record 41 of Set 18 | taree
# Processing Record 42 of Set 18 | arraial do cabo
# Processing Record 43 of Set 18 | vestmannaeyjar
# Processing Record 44 of Set 18 | santa maria
# Processing Record 45 of Set 18 | chuy
# Processing Record 46 of Set 18 | hit
# Processing Record 47 of Set 18 | genhe
# Processing Record 48 of Set 18 | itarema
# Processing Record 49 of Set 18 | longyearbyen
# Processing Record 50 of Set 18 | pasighat
# Processing Record 1 of Set 19 | kasempa
# Processing Record 2 of Set 19 | pemba
# Processing Record 3 of Set 19 | jamestown
# Processing Record 4 of Set 19 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 19 | ilongero
# Processing Record 6 of Set 19 | mikhaylov
# Processing Record 7 of Set 19 | bethel
# Processing Record 8 of Set 19 | raudeberg
# Processing Record 9 of Set 19 | guerrero negro
# Processing Record 10 of Set 19 | karaul
# City not found. Skipping...
# Processing Record 11 of Set 19 | polovinnoye
# Processing Record 12 of Set 19 | santa helena
# Processing Record 13 of Set 19 | temaraia
# City not found. Skipping...
# Processing Record 14 of Set 19 | sao joao do piaui
# Processing Record 15 of Set 19 | zolochiv
# Processing Record 16 of Set 19 | kostyantynivka
# Processing Record 17 of Set 19 | tiquicheo
# Processing Record 18 of Set 19 | saldanha
# Processing Record 19 of Set 19 | sohag
# Processing Record 20 of Set 19 | north bend
# Processing Record 21 of Set 19 | marawi
# Processing Record 22 of Set 19 | yulara
# Processing Record 23 of Set 19 | severo-yeniseyskiy
# Processing Record 24 of Set 19 | coari
# Processing Record 25 of Set 19 | panama city
# Processing Record 26 of Set 19 | grand centre
# City not found. Skipping...
# Processing Record 27 of Set 19 | seminole
# Processing Record 28 of Set 19 | san cristobal
# Processing Record 29 of Set 19 | flinders
# Processing Record 30 of Set 19 | severo-kurilsk
# Processing Record 31 of Set 19 | qaqortoq
# Processing Record 32 of Set 19 | qui nhon
# Processing Record 33 of Set 19 | khanpur
# Processing Record 34 of Set 19 | turka
# Processing Record 35 of Set 19 | sobolevo
# Processing Record 36 of Set 19 | usta muhammad
# Processing Record 37 of Set 19 | samalaeulu
# City not found. Skipping...
# Processing Record 38 of Set 19 | bayan
# Processing Record 39 of Set 19 | minab
# Processing Record 40 of Set 19 | margate
# Processing Record 41 of Set 19 | chagda
# City not found. Skipping...
# Processing Record 42 of Set 19 | east london
# Processing Record 43 of Set 19 | dagana
# Processing Record 44 of Set 19 | konevo
# Processing Record 45 of Set 19 | mokhsogollokh
# Processing Record 46 of Set 19 | aykhal
# Processing Record 47 of Set 19 | turukhansk
# Processing Record 48 of Set 19 | winslow
# Processing Record 49 of Set 19 | castro
# Processing Record 50 of Set 19 | cefalu
# Processing Record 1 of Set 20 | pizarro
# Processing Record 2 of Set 20 | port alfred
# Processing Record 3 of Set 20 | te anau
# Processing Record 4 of Set 20 | bafoulabe
# Processing Record 5 of Set 20 | cortes
# Processing Record 6 of Set 20 | lorengau
# Processing Record 7 of Set 20 | khash
# Processing Record 8 of Set 20 | rameshki
# Processing Record 9 of Set 20 | ormara
# Processing Record 10 of Set 20 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 20 | touho
# Processing Record 12 of Set 20 | noumea
# Processing Record 13 of Set 20 | moron
# Processing Record 14 of Set 20 | nishihara
# Processing Record 15 of Set 20 | guadalupe victoria
# Processing Record 16 of Set 20 | the valley
# Processing Record 17 of Set 20 | torbay
# Processing Record 18 of Set 20 | aswan
# Processing Record 19 of Set 20 | rio gallegos
# Processing Record 20 of Set 20 | bacolod
# Processing Record 21 of Set 20 | sitka
# Processing Record 22 of Set 20 | bargal
# City not found. Skipping...
# Processing Record 23 of Set 20 | geraldton
# Processing Record 24 of Set 20 | hervey bay
# Processing Record 25 of Set 20 | hualmay
# Processing Record 26 of Set 20 | sulina
# Processing Record 27 of Set 20 | kankon
# Processing Record 28 of Set 20 | grindavik
# Processing Record 29 of Set 20 | mar del plata
# Processing Record 30 of Set 20 | galveston
# Processing Record 31 of Set 20 | homer
# Processing Record 32 of Set 20 | vung tau
# Processing Record 33 of Set 20 | mana
# Processing Record 34 of Set 20 | pangnirtung
# Processing Record 35 of Set 20 | bambous virieux
# Processing Record 36 of Set 20 | tura
# Processing Record 37 of Set 20 | vila
# Processing Record 38 of Set 20 | smolyaninovo
# Processing Record 39 of Set 20 | flin flon
# Processing Record 40 of Set 20 | casino
# Processing Record 41 of Set 20 | nguiu
# City not found. Skipping...
# Processing Record 42 of Set 20 | ilulissat
# Processing Record 43 of Set 20 | wagar
# Processing Record 44 of Set 20 | bethanien
# Processing Record 45 of Set 20 | kropotkin
# Processing Record 46 of Set 20 | kavieng
# Processing Record 47 of Set 20 | lasa
# Processing Record 48 of Set 20 | ovsyanka
# Processing Record 49 of Set 20 | calbuco
# Processing Record 50 of Set 20 | upernavik
# Processing Record 1 of Set 21 | kruisfontein
# Processing Record 2 of Set 21 | neuquen
# Processing Record 3 of Set 21 | oranjemund
# Processing Record 4 of Set 21 | frankfort
# Processing Record 5 of Set 21 | araucaria
# Processing Record 6 of Set 21 | khatanga
# Processing Record 7 of Set 21 | osoyoos
# Processing Record 8 of Set 21 | saskylakh
# Processing Record 9 of Set 21 | taoudenni
# Processing Record 10 of Set 21 | tudela
# Processing Record 11 of Set 21 | komsomolskiy
# Processing Record 12 of Set 21 | scicli
# Processing Record 13 of Set 21 | manokwari
# Processing Record 14 of Set 21 | tottori
# Processing Record 15 of Set 21 | klaksvik
# Processing Record 16 of Set 21 | port elizabeth
# Processing Record 17 of Set 21 | tapes
# Processing Record 18 of Set 21 | khudumelapye
# Processing Record 19 of Set 21 | chhatak
# Processing Record 20 of Set 21 | prado
# Processing Record 21 of Set 21 | nambucca heads
# Processing Record 22 of Set 21 | biak
# Processing Record 23 of Set 21 | tabas
# Processing Record 24 of Set 21 | billings
# Processing Record 25 of Set 21 | matagami
# Processing Record 26 of Set 21 | gornyye klyuchi
# Processing Record 27 of Set 21 | bay city
# Processing Record 28 of Set 21 | constitucion
# Processing Record 29 of Set 21 | lewisburg
# Processing Record 30 of Set 21 | kenai
# Processing Record 31 of Set 21 | college
# Processing Record 32 of Set 21 | vardo
# Processing Record 33 of Set 21 | la orilla
# Processing Record 34 of Set 21 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 21 | galle
# Processing Record 36 of Set 21 | boralday
# Processing Record 37 of Set 21 | petropavlovsk-kamchatskiy
# Processing Record 38 of Set 21 | sucre
# Processing Record 39 of Set 21 | jardim
# Processing Record 40 of Set 21 | sur
# Processing Record 41 of Set 21 | tabiauea
# City not found. Skipping...
# Processing Record 42 of Set 21 | sharlyk
# Processing Record 43 of Set 21 | fallon
# Processing Record 44 of Set 21 | trenggalek
# Processing Record 45 of Set 21 | yablochnyy
# Processing Record 46 of Set 21 | male
# Processing Record 47 of Set 21 | lagoa
# Processing Record 48 of Set 21 | pisco
# Processing Record 49 of Set 21 | khani
# Processing Record 50 of Set 21 | moundou
# Processing Record 1 of Set 22 | port hardy
# Processing Record 2 of Set 22 | juifang
# City not found. Skipping...
# Processing Record 3 of Set 22 | vao
# Processing Record 4 of Set 22 | hays
# Processing Record 5 of Set 22 | lewistown
# Processing Record 6 of Set 22 | skalistyy
# City not found. Skipping...
# Processing Record 7 of Set 22 | alyangula
# Processing Record 8 of Set 22 | kahului
# Processing Record 9 of Set 22 | fairbanks
# Processing Record 10 of Set 22 | maceio
# Processing Record 11 of Set 22 | cherskiy
# Processing Record 12 of Set 22 | cam ranh
# Processing Record 13 of Set 22 | jacareacanga
# Processing Record 14 of Set 22 | tiznit
# Processing Record 15 of Set 22 | mongoumba
# Processing Record 16 of Set 22 | necochea
# Processing Record 17 of Set 22 | ixtapa
# Processing Record 18 of Set 22 | sao joao da barra
# Processing Record 19 of Set 22 | azimur
# City not found. Skipping...
# Processing Record 20 of Set 22 | kodiak
# Processing Record 21 of Set 22 | koutsouras
# Processing Record 22 of Set 22 | gat
# Processing Record 23 of Set 22 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 22 | aksu
# Processing Record 25 of Set 22 | kamenskoye
# City not found. Skipping...
# Processing Record 26 of Set 22 | broken hill
# Processing Record 27 of Set 22 | takestan
# Processing Record 28 of Set 22 | richards bay
# Processing Record 29 of Set 22 | carballo
# Processing Record 30 of Set 22 | asau
# Processing Record 31 of Set 22 | gamboma
# Processing Record 32 of Set 22 | ahuimanu
# Processing Record 33 of Set 22 | ust-ilimsk
# Processing Record 34 of Set 22 | kpandu
# Processing Record 35 of Set 22 | ulladulla
# Processing Record 36 of Set 22 | antsla
# Processing Record 37 of Set 22 | tempio pausania
# Processing Record 38 of Set 22 | neyshabur
# Processing Record 39 of Set 22 | udachnyy
# Processing Record 40 of Set 22 | dzilam gonzalez
# Processing Record 41 of Set 22 | loandjili
# Processing Record 42 of Set 22 | rongcheng
# Processing Record 43 of Set 22 | rio grande
# Processing Record 44 of Set 22 | gardan diwal
# City not found. Skipping...
# Processing Record 45 of Set 22 | bereda
# Processing Record 46 of Set 22 | zakopane
# Processing Record 47 of Set 22 | kusa
# Processing Record 48 of Set 22 | santa cruz del sur
# Processing Record 49 of Set 22 | kilmez
# City not found. Skipping...
# Processing Record 50 of Set 22 | kotelnikovo
# Processing Record 1 of Set 23 | ransang
# Processing Record 2 of Set 23 | paytug
# City not found. Skipping...
# Processing Record 3 of Set 23 | mahibadhoo
# Processing Record 4 of Set 23 | poum
# Processing Record 5 of Set 23 | kodinsk
# Processing Record 6 of Set 23 | bambanglipuro
# Processing Record 7 of Set 23 | chapais
# Processing Record 8 of Set 23 | saint anthony
# Processing Record 9 of Set 23 | opaka
# Processing Record 10 of Set 23 | zhangye
# Processing Record 11 of Set 23 | ucluelet
# Processing Record 12 of Set 23 | big bend
# Processing Record 13 of Set 23 | maarianhamina
# Processing Record 14 of Set 23 | yorkton
# Processing Record 15 of Set 23 | kyaikto
# Processing Record 16 of Set 23 | morehead
# Processing Record 17 of Set 23 | bozuyuk
# Processing Record 18 of Set 23 | paracuru
# Processing Record 19 of Set 23 | kudahuvadhoo
# Processing Record 20 of Set 23 | buldana
# Processing Record 21 of Set 23 | birobidzhan
# Processing Record 22 of Set 23 | abong mbang
# Processing Record 23 of Set 23 | dongli
# Processing Record 24 of Set 23 | ponta do sol
# Processing Record 25 of Set 23 | zhaotong
# Processing Record 26 of Set 23 | varhaug
# Processing Record 27 of Set 23 | whitehorse
# Processing Record 28 of Set 23 | marsh harbour
# Processing Record 29 of Set 23 | asfi
# Processing Record 30 of Set 23 | orikum
# Processing Record 31 of Set 23 | bengkulu
# Processing Record 32 of Set 23 | cururupu
# Processing Record 33 of Set 23 | farafangana
# Processing Record 34 of Set 23 | camana
# Processing Record 35 of Set 23 | kangalassy
# Processing Record 36 of Set 23 | tabou
# Processing Record 37 of Set 23 | sinnamary
# Processing Record 38 of Set 23 | sozopol
# Processing Record 39 of Set 23 | lodingen
# Processing Record 40 of Set 23 | barrow
# Processing Record 41 of Set 23 | ngukurr
# City not found. Skipping...
# Processing Record 42 of Set 23 | berlevag
# Processing Record 43 of Set 23 | cananea
# Processing Record 44 of Set 23 | pitimbu
# Processing Record 45 of Set 23 | bulalacao
# Processing Record 46 of Set 23 | yinchuan
# Processing Record 47 of Set 23 | rundu
# Processing Record 48 of Set 23 | kijang
# Processing Record 49 of Set 23 | saint-joseph
# Processing Record 50 of Set 23 | virden
# Processing Record 1 of Set 24 | feijo
# Processing Record 2 of Set 24 | southbridge
# Processing Record 3 of Set 24 | lakewood
# Processing Record 4 of Set 24 | torrijos
# Processing Record 5 of Set 24 | dezful
# Processing Record 6 of Set 24 | chara
# Processing Record 7 of Set 24 | caibarien
# Processing Record 8 of Set 24 | lantawan
# Processing Record 9 of Set 24 | lloro
# Processing Record 10 of Set 24 | morant bay
# Processing Record 11 of Set 24 | bara
# Processing Record 12 of Set 24 | karaton
# Processing Record 13 of Set 24 | caravelas
# Processing Record 14 of Set 24 | ostrovnoy
# Processing Record 15 of Set 24 | groa
# Processing Record 16 of Set 24 | dunedin
# Processing Record 17 of Set 24 | skibbereen
# Processing Record 18 of Set 24 | outjo
# Processing Record 19 of Set 24 | tonosho
# Processing Record 20 of Set 24 | touros
# Processing Record 21 of Set 24 | hovd
# Processing Record 22 of Set 24 | narsaq
# Processing Record 23 of Set 24 | tefe
# Processing Record 24 of Set 24 | mandalgovi
# Processing Record 25 of Set 24 | honningsvag
# Processing Record 26 of Set 24 | carutapera
# Processing Record 27 of Set 24 | brae
# Processing Record 28 of Set 24 | okmulgee
# Processing Record 29 of Set 24 | naze
# Processing Record 30 of Set 24 | milkovo
# Processing Record 31 of Set 24 | goderich
# Processing Record 32 of Set 24 | alausi
# Processing Record 33 of Set 24 | toppenish
# Processing Record 34 of Set 24 | krasnoselkup
# Processing Record 35 of Set 24 | colares
# Processing Record 36 of Set 24 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 24 | zyryanka
# Processing Record 38 of Set 24 | boca de parita
# Processing Record 39 of Set 24 | jinchengjiang
# City not found. Skipping...
# Processing Record 40 of Set 24 | san patricio
# Processing Record 41 of Set 24 | namatanai
# Processing Record 42 of Set 24 | batticaloa
# Processing Record 43 of Set 24 | isla vista
# Processing Record 44 of Set 24 | west wendover
# Processing Record 45 of Set 24 | verkh-usugli
# Processing Record 46 of Set 24 | champerico
# Processing Record 47 of Set 24 | mayumba
# Processing Record 48 of Set 24 | port macquarie
# Processing Record 49 of Set 24 | los llanos de aridane
# Processing Record 50 of Set 24 | ust-ishim
# Processing Record 1 of Set 25 | vengerovo
# Processing Record 2 of Set 25 | presidencia roque saenz pena
# Processing Record 3 of Set 25 | hambantota
# Processing Record 4 of Set 25 | kungalv
# Processing Record 5 of Set 25 | beringovskiy
# Processing Record 6 of Set 25 | villa carlos paz
# Processing Record 7 of Set 25 | dakar
# Processing Record 8 of Set 25 | hatillo
# Processing Record 9 of Set 25 | longfeng
# Processing Record 10 of Set 25 | westport
# Processing Record 11 of Set 25 | sorland
# Processing Record 12 of Set 25 | bugulma
# Processing Record 13 of Set 25 | yangjiang
# Processing Record 14 of Set 25 | staryy nadym
# Processing Record 15 of Set 25 | traverse city
# Processing Record 16 of Set 25 | madras
# Processing Record 17 of Set 25 | kattivakkam
# Processing Record 18 of Set 25 | lubango
# Processing Record 19 of Set 25 | bilma
# Processing Record 20 of Set 25 | krasnyy oktyabr
# Processing Record 21 of Set 25 | port hawkesbury
# Processing Record 22 of Set 25 | harnosand
# Processing Record 23 of Set 25 | niamey
# Processing Record 24 of Set 25 | kazalinsk
# City not found. Skipping...
# Processing Record 25 of Set 25 | ancud
# Processing Record 26 of Set 25 | lyman
# Processing Record 27 of Set 25 | arrecife
# Processing Record 28 of Set 25 | knyaze-volkonskoye
# Processing Record 29 of Set 25 | simao
# Processing Record 30 of Set 25 | tarbes
# Processing Record 31 of Set 25 | ampanihy
# Processing Record 32 of Set 25 | kimbe
# Processing Record 33 of Set 25 | arman
# Processing Record 34 of Set 25 | altamira
# Processing Record 35 of Set 25 | pyu
# Processing Record 36 of Set 25 | shingu
# Processing Record 37 of Set 25 | hermiston
# Processing Record 38 of Set 25 | alice springs
# Processing Record 39 of Set 25 | eskilstuna
# Processing Record 40 of Set 25 | codrington
# Processing Record 41 of Set 25 | prachuap khiri khan
# Processing Record 42 of Set 25 | naryan-mar
# Processing Record 43 of Set 25 | catuday
# Processing Record 44 of Set 25 | kangaatsiaq
# Processing Record 45 of Set 25 | dogondoutchi
# Processing Record 46 of Set 25 | namibe
# Processing Record 47 of Set 25 | laguna
# Processing Record 48 of Set 25 | halalo
# City not found. Skipping...
# Processing Record 49 of Set 25 | port hedland
# Processing Record 50 of Set 25 | dukat
# Processing Record 1 of Set 26 | guarapari
# Processing Record 2 of Set 26 | marv dasht
# City not found. Skipping...
# Processing Record 3 of Set 26 | masvingo
# Processing Record 4 of Set 26 | seguela
# Processing Record 5 of Set 26 | rorvik
# Processing Record 6 of Set 26 | ulaangom
# Processing Record 7 of Set 26 | tanete
# Processing Record 8 of Set 26 | almaznyy
# Processing Record 9 of Set 26 | padang
# Processing Record 10 of Set 26 | kushima
# Processing Record 11 of Set 26 | rancho palos verdes
# Processing Record 12 of Set 26 | cajaruro
# Processing Record 13 of Set 26 | diamantino
# Processing Record 14 of Set 26 | khonsa
# Processing Record 15 of Set 26 | grand-santi
# Processing Record 16 of Set 26 | celestun
# Processing Record 17 of Set 26 | ketchikan
# Processing Record 18 of Set 26 | son la
# Processing Record 19 of Set 26 | vyazemskiy
# Processing Record 20 of Set 26 | basna
# Processing Record 21 of Set 26 | dolbeau
# City not found. Skipping...
# Processing Record 22 of Set 26 | coquimbo
# Processing Record 23 of Set 26 | talakan
# Processing Record 24 of Set 26 | dali
# Processing Record 25 of Set 26 | hamilton
# Processing Record 26 of Set 26 | deputatskiy
# Processing Record 27 of Set 26 | yarada
# Processing Record 28 of Set 26 | mochumi
# Processing Record 29 of Set 26 | dourbali
# Processing Record 30 of Set 26 | enshi
# Processing Record 31 of Set 26 | puerto quijarro
# Processing Record 32 of Set 26 | ola
# Processing Record 33 of Set 26 | redmond
# Processing Record 34 of Set 26 | kismayo
# Processing Record 35 of Set 26 | daru
# Processing Record 36 of Set 26 | kyrylivka
# Processing Record 37 of Set 26 | quatre cocos
# Processing Record 38 of Set 26 | price
# Processing Record 39 of Set 26 | two hills
# Processing Record 40 of Set 26 | broome
# Processing Record 41 of Set 26 | pevek
# Processing Record 42 of Set 26 | hunza
# City not found. Skipping...
# Processing Record 43 of Set 26 | karpathos
# Processing Record 44 of Set 26 | soyo
# Processing Record 45 of Set 26 | starkville
# Processing Record 46 of Set 26 | tymovskoye
# Processing Record 47 of Set 26 | ishigaki
# Processing Record 48 of Set 26 | kozulka
# Processing Record 49 of Set 26 | brejo santo
# Processing Record 50 of Set 26 | olovyannaya
# Processing Record 1 of Set 27 | gamba
# Processing Record 2 of Set 27 | el bagre
# Processing Record 3 of Set 27 | neiafu
# Processing Record 4 of Set 27 | beisfjord
# Processing Record 5 of Set 27 | camocim
# Processing Record 6 of Set 27 | kanniyakumari
# Processing Record 7 of Set 27 | kupang
# Processing Record 8 of Set 27 | lawrenceburg
# Processing Record 9 of Set 27 | praya
# Processing Record 10 of Set 27 | wattegama
# Processing Record 11 of Set 27 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 27 | henties bay
# Processing Record 13 of Set 27 | cairns
# Processing Record 14 of Set 27 | santa fe
# Processing Record 15 of Set 27 | marolambo
# Processing Record 16 of Set 27 | mecca
# Processing Record 17 of Set 27 | ligayan
# Processing Record 18 of Set 27 | tokur
# Processing Record 19 of Set 27 | tazovskiy
# Processing Record 20 of Set 27 | lashio
# Processing Record 21 of Set 27 | butembo
# Processing Record 22 of Set 27 | puerto madryn
# Processing Record 23 of Set 27 | saint-pierre
# Processing Record 24 of Set 27 | artesia
# Processing Record 25 of Set 27 | novikovo
# Processing Record 26 of Set 27 | abu samrah
# Processing Record 27 of Set 27 | garowe
# Processing Record 28 of Set 27 | freeport
# Processing Record 29 of Set 27 | abha
# Processing Record 30 of Set 27 | westerly
# Processing Record 31 of Set 27 | faya
# Processing Record 32 of Set 27 | seabra
# Processing Record 33 of Set 27 | airai
# Processing Record 34 of Set 27 | cockburn town
# Processing Record 35 of Set 27 | kargasok
# Processing Record 36 of Set 27 | huambo
# Processing Record 37 of Set 27 | moba
# Processing Record 38 of Set 27 | penzance
# Processing Record 39 of Set 27 | husavik
# Processing Record 40 of Set 27 | soure
# Processing Record 41 of Set 27 | wad rawah
# Processing Record 42 of Set 27 | jieshi
# Processing Record 43 of Set 27 | moisei
# Processing Record 44 of Set 27 | road town
# Processing Record 45 of Set 27 | meulaboh
# Processing Record 46 of Set 27 | atambua
# Processing Record 47 of Set 27 | caucaia
# Processing Record 48 of Set 27 | acarau
# Processing Record 49 of Set 27 | mehamn
# Processing Record 50 of Set 27 | tenosique
# Processing Record 1 of Set 28 | rivera
# Processing Record 2 of Set 28 | jaisalmer
# Processing Record 3 of Set 28 | soe
# Processing Record 4 of Set 28 | inhambane
# Processing Record 5 of Set 28 | trinidad
# Processing Record 6 of Set 28 | uvinza
# Processing Record 7 of Set 28 | kaeo
# Processing Record 8 of Set 28 | cidreira
# Processing Record 9 of Set 28 | udayagiri
# Processing Record 10 of Set 28 | changji
# Processing Record 11 of Set 28 | vanavara
# Processing Record 12 of Set 28 | bull savanna
# Processing Record 13 of Set 28 | samarai
# Processing Record 14 of Set 28 | la ronge
# Processing Record 15 of Set 28 | fulton
# Processing Record 16 of Set 28 | kununurra
# Processing Record 17 of Set 28 | lysyye gory
# Processing Record 18 of Set 28 | andevoranto
# City not found. Skipping...
# Processing Record 19 of Set 28 | saint-francois
# Processing Record 20 of Set 28 | udomlya
# Processing Record 21 of Set 28 | kavaratti
# Processing Record 22 of Set 28 | swift current
# Processing Record 23 of Set 28 | vaitape
# Processing Record 24 of Set 28 | artyk
# City not found. Skipping...
# Processing Record 25 of Set 28 | onguday
# Processing Record 26 of Set 28 | kalomo
# City not found. Skipping...
# Processing Record 27 of Set 28 | douglas
# Processing Record 28 of Set 28 | baruun-urt
# Processing Record 29 of Set 28 | santa ines
# Processing Record 30 of Set 28 | paradwip
# City not found. Skipping...
# Processing Record 31 of Set 28 | eureka
# Processing Record 32 of Set 28 | taiyuan
# Processing Record 33 of Set 28 | takoradi
# Processing Record 34 of Set 28 | kaputa
# Processing Record 35 of Set 28 | kamaishi
# Processing Record 36 of Set 28 | kuminskiy
# Processing Record 37 of Set 28 | praia da vitoria
# Processing Record 38 of Set 28 | rabo de peixe
# Processing Record 39 of Set 28 | srednekolymsk
# Processing Record 40 of Set 28 | lazaro cardenas
# Processing Record 41 of Set 28 | labuhan
# Processing Record 42 of Set 28 | misratah
# Processing Record 43 of Set 28 | leua
# Processing Record 44 of Set 28 | chimoio
# Processing Record 45 of Set 28 | egvekinot
# Processing Record 46 of Set 28 | saint stephen
# Processing Record 47 of Set 28 | birao
# Processing Record 48 of Set 28 | sindou
# Processing Record 49 of Set 28 | bolungarvik
# City not found. Skipping...
# Processing Record 50 of Set 28 | tadian
# Processing Record 1 of Set 29 | garelochhead
# Processing Record 2 of Set 29 | mackay
# Processing Record 3 of Set 29 | lethem
# Processing Record 4 of Set 29 | aranos
# Processing Record 5 of Set 29 | leningradskiy
# Processing Record 6 of Set 29 | gazli
# Processing Record 7 of Set 29 | mareeba
# Processing Record 8 of Set 29 | vostok
# Processing Record 9 of Set 29 | ijaki
# City not found. Skipping...
# Processing Record 10 of Set 29 | esna
# Processing Record 11 of Set 29 | marzuq
# Processing Record 12 of Set 29 | high level
# Processing Record 13 of Set 29 | rawah
# Processing Record 14 of Set 29 | mandera
# Processing Record 15 of Set 29 | gorin
# Processing Record 16 of Set 29 | thessalon
# Processing Record 17 of Set 29 | narwar
# Processing Record 18 of Set 29 | ranong
# Processing Record 19 of Set 29 | luwero
# Processing Record 20 of Set 29 | general roca
# Processing Record 21 of Set 29 | weligama
# Processing Record 22 of Set 29 | yingkou
# Processing Record 23 of Set 29 | mount isa
# Processing Record 24 of Set 29 | alotau
# City not found. Skipping...
# Processing Record 25 of Set 29 | umea
# Processing Record 26 of Set 29 | mabaruma
# Processing Record 27 of Set 29 | laredo
# Processing Record 28 of Set 29 | oliveira dos brejinhos
# Processing Record 29 of Set 29 | isangel
# Processing Record 30 of Set 29 | isabela
# Processing Record 31 of Set 29 | capao da canoa
# Processing Record 32 of Set 29 | camacha
# Processing Record 33 of Set 29 | dourados
# Processing Record 34 of Set 29 | vaxjo
# Processing Record 35 of Set 29 | roald
# Processing Record 36 of Set 29 | yichang
# Processing Record 37 of Set 29 | kamina
# Processing Record 38 of Set 29 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 29 | igurubi
# Processing Record 40 of Set 29 | fethiye
# Processing Record 41 of Set 29 | abyek
# Processing Record 42 of Set 29 | maun
# Processing Record 43 of Set 29 | ghanzi
# Processing Record 44 of Set 29 | yaan
# Processing Record 45 of Set 29 | korla
# Processing Record 46 of Set 29 | pangai
# Processing Record 47 of Set 29 | avera
# Processing Record 48 of Set 29 | clarksburg
# Processing Record 49 of Set 29 | beyneu
# Processing Record 50 of Set 29 | andrelandia
# Processing Record 1 of Set 30 | awbari
# Processing Record 2 of Set 30 | bouloupari
# Processing Record 3 of Set 30 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 4 of Set 30 | calama
# Processing Record 5 of Set 30 | zhicheng
# Processing Record 6 of Set 30 | san vicente
# Processing Record 7 of Set 30 | willowmore
# Processing Record 8 of Set 30 | alibunar
# Processing Record 9 of Set 30 | acoyapa
# Processing Record 10 of Set 30 | padampur
# Processing Record 11 of Set 30 | golspie
# Processing Record 12 of Set 30 | port blair
# Processing Record 13 of Set 30 | mopti
# Processing Record 14 of Set 30 | letka
# Processing Record 15 of Set 30 | doha
# Processing Record 16 of Set 30 | baripada
# Processing Record 17 of Set 30 | poltava
# Processing Record 18 of Set 30 | challans
# Processing Record 19 of Set 30 | igarka
# Processing Record 20 of Set 30 | fenoarivo
# Processing Record 21 of Set 30 | talkha
# Processing Record 22 of Set 30 | kamen-rybolov
# Processing Record 23 of Set 30 | manado
# Processing Record 24 of Set 30 | maltahohe
# Processing Record 25 of Set 30 | muros
# Processing Record 26 of Set 30 | vila velha
# Processing Record 27 of Set 30 | mumford
# Processing Record 28 of Set 30 | charyshskoye
# Processing Record 29 of Set 30 | bonfim
# Processing Record 30 of Set 30 | inderborskiy
# City not found. Skipping...
# Processing Record 31 of Set 30 | kloulklubed
# Processing Record 32 of Set 30 | kingston
# Processing Record 33 of Set 30 | puerto rico
# Processing Record 34 of Set 30 | issia
# Processing Record 35 of Set 30 | behshahr
# Processing Record 36 of Set 30 | ballina
# Processing Record 37 of Set 30 | half moon bay
# Processing Record 38 of Set 30 | houma
# Processing Record 39 of Set 30 | maldonado
# Processing Record 40 of Set 30 | mirabad
# Processing Record 41 of Set 30 | iida
# Processing Record 42 of Set 30 | ajaccio
# Processing Record 43 of Set 30 | sao jose de ribamar
# Processing Record 44 of Set 30 | ruatoria
# City not found. Skipping...
# Processing Record 45 of Set 30 | moose factory
# Processing Record 46 of Set 30 | virginia beach
# Processing Record 47 of Set 30 | leiyang
# Processing Record 48 of Set 30 | codajas
# Processing Record 49 of Set 30 | yei
# Processing Record 50 of Set 30 | palmer
# Processing Record 1 of Set 31 | safidon
# Processing Record 2 of Set 31 | dossor
# Processing Record 3 of Set 31 | lolua
# City not found. Skipping...
# Processing Record 4 of Set 31 | guhagar
# Processing Record 5 of Set 31 | moussoro
# Processing Record 6 of Set 31 | ponta delgada
# Processing Record 7 of Set 31 | payo
# Processing Record 8 of Set 31 | prince rupert
# Processing Record 9 of Set 31 | vysokogornyy
# Processing Record 10 of Set 31 | buraydah
# Processing Record 11 of Set 31 | karkaralinsk
# City not found. Skipping...
# Processing Record 12 of Set 31 | zhuhai
# ------------------------------
# Data Retrieval is Complete
# ------------------------------

# %%
len(city_data)
# Out:
# 704

# %%
# Convert the array to pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0              Zhigansk  66.7697  123.3711     33.19        98         100
# 1              Sisimiut  66.9395  -53.6735     41.95        60           4
# 2            Chokurdakh  70.6333  147.9167    -15.03        98          15
# 3      Diego De Almagro -26.3667  -70.0500     72.66        28           0
# 4  Vila Franca Do Campo  37.7167  -25.4333     59.00        88          75
# 5        Cabo San Lucas  22.8909 -109.9124     80.60        41           1
# 6               Rikitea -23.1203 -134.9692     78.58        70          99
# 7             Coihaique -45.5752  -72.0662     53.60        76          90
# 8                  Hilo  19.7297 -155.0900     69.80        83          90
# 9             Cape Town -33.9258   18.4232     64.00        77           0
#
#    Wind Speed Country Current Description
# 0       10.04      RU          light snow
# 1        5.46      GL           clear sky
# 2        3.85      RU          few clouds
# 3       10.83      CL           clear sky
# 4       17.27      PT       broken clouds
# 5        8.05      MX           clear sky
# 6       16.15      PF     overcast clouds
# 7        3.44      CL     overcast clouds
# 8        4.61      US       moderate rain
# 9       13.80      ZA           clear sky

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]

city_data_df.head(10)
# Out:
#                    City Country      Lat       Lng  Max Temp  Humidity  \
# 0              Zhigansk      RU  66.7697  123.3711     33.19        98
# 1              Sisimiut      GL  66.9395  -53.6735     41.95        60
# 2            Chokurdakh      RU  70.6333  147.9167    -15.03        98
# 3      Diego De Almagro      CL -26.3667  -70.0500     72.66        28
# 4  Vila Franca Do Campo      PT  37.7167  -25.4333     59.00        88
# 5        Cabo San Lucas      MX  22.8909 -109.9124     80.60        41
# 6               Rikitea      PF -23.1203 -134.9692     78.58        70
# 7             Coihaique      CL -45.5752  -72.0662     53.60        76
# 8                  Hilo      US  19.7297 -155.0900     69.80        83
# 9             Cape Town      ZA -33.9258   18.4232     64.00        77
#
#    Cloudiness  Wind Speed Current Description
# 0         100       10.04          light snow
# 1           4        5.46           clear sky
# 2          15        3.85          few clouds
# 3           0       10.83           clear sky
# 4          75       17.27       broken clouds
# 5           1        8.05           clear sky
# 6          99       16.15     overcast clouds
# 7          90        3.44     overcast clouds
# 8          90        4.61       moderate rain
# 9           0       13.80           clear sky

# %%
# Create the output file (CSV)
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
